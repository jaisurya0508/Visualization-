# %% [markdown]
# ## <center><h1>Data Visualization</h1></center>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("Random integer vector:",np.random.randint(1,10)) #randint (low, high, # of samples to be drawn)
print ("\nRandom integer matrix")
# Out:
# Random integer vector: 3
#
# Random integer matrix

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df=pd.DataFrame(randn(10),index=pd.date_range('2020-09-10',periods=10), columns=['value'])
df.head()
# Out:
#                value
# 2020-09-10  0.025069
# 2020-09-11 -0.114121
# 2020-09-12  0.067610
# 2020-09-13  0.835327
# 2020-09-14 -1.803139

# %%
ts = pd.Series(randn(10), index = pd.date_range('2020-06-07', periods = 10))
ts.head()
# Out:
# 2020-06-07   -0.272549
# 2020-06-08    0.778938
# 2020-06-09    0.397436
# 2020-06-10    1.335287
# 2020-06-11    0.236610
# Freq: D, dtype: float64

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2020-09-10  0.025069
# 2020-09-11 -0.089052
# 2020-09-12 -0.021443
# 2020-09-13  0.813884
# 2020-09-14 -0.989254

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2020-06-07   -0.272549
# 2020-06-08    0.506389
# 2020-06-09    0.903825
# 2020-06-10    2.239113
# 2020-06-11    2.475723
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0,0.5,'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='barh')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['fare'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -2.201815 -0.227164  0.085576  1.939336
# 1  0.585592 -1.056526  0.527082  1.084776
# 2  0.324031 -0.145891  1.470539  0.595590
# 3  2.284419  0.187912  0.994971 -1.631028
# 4  0.576843  1.385378 -1.372374  0.158746
# 5  0.603910 -0.317935  1.307329 -0.824651
# 6  0.275943 -0.175996  0.125737 -0.999663
# 7 -1.033596  0.444656 -1.094229 -1.674161
# 8  0.042550  0.824995  1.373094 -0.434747
# 9 -2.185309  0.161240  1.384461 -0.459360

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
# 5      0.3
# 6     -0.5
# 7      0.0
# 8     -0.5
# 9      0.2
# 10     0.6
# 11    -0.3
# 12    -0.4
# 13     0.0
# 14     1.0
# 15     0.4
# 16    -0.5
# 17    -0.4
# 18     0.3
# 19     0.0
# 20    -0.4
# 21     0.3
# 22    -0.1
# 23    -0.3
# 24     0.1
# 25    -0.4
# 26     0.4
# 27     0.1
# 28    -0.1
# 29    -0.2
#       ...
# 120    1.0
# 121   -0.4
# 122    0.0
# 123   -0.1
# 124    0.6
# 125   -0.1
# 126   -0.4
# 127    0.2
# 128   -0.2
# 129    0.2
# 130   -0.2
# 131    1.0
# 132   -1.0
# 133    0.0
# 134   -0.2
# 135    0.4
# 136    0.4
# 137   -0.3
# 138   -0.1
# 139    0.1
# 140    0.0
# 141    0.0
# 142   -0.4
# 143    0.5
# 144    0.1
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001819A813CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001819A878400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001819A89FA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001819A8D3160>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 180)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (10, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000011207E3D358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000011207E729E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000011207E9BF60>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000011207D591D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000011207D83F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000011207DB4550>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000112085CE940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000112084E3908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001120815CE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000011208494438>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
